# %%
from google import genai
from google.genai import types
import base64

def generate():
  client = genai.Client(
      vertexai=True,
      project="sandbox2-363416",
      location="us-central1"
  )

  video1 = types.Part.from_uri(
      file_uri="https://www.youtube.com/watch?v=-Fju4UajL7g",
      mime_type="video/*",
  )

  model = "gemini-2.0-flash-exp"
  contents = [
    types.Content(
      role="user",
      parts=[
        video1,
        types.Part.from_text("""Can you provide the transcript""")
      ]
    )
  ]
  generate_content_config = types.GenerateContentConfig(
    temperature = 1,
    top_p = 0.95,
    max_output_tokens = 8192,
    response_modalities = ["TEXT"],
    safety_settings = [types.SafetySetting(
      category="HARM_CATEGORY_HATE_SPEECH",
      threshold="OFF"
    ),types.SafetySetting(
      category="HARM_CATEGORY_DANGEROUS_CONTENT",
      threshold="OFF"
    ),types.SafetySetting(
      category="HARM_CATEGORY_SEXUALLY_EXPLICIT",
      threshold="OFF"
    ),types.SafetySetting(
      category="HARM_CATEGORY_HARASSMENT",
      threshold="OFF"
    )],
  )

  for chunk in client.models.generate_content_stream(
    model = model,
    contents = contents,
    config = generate_content_config,
    ):
    print(chunk, end="")

generate()
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[1], line 54
#      47   for chunk in client.models.generate_content_stream(
#      48     model = model,
#      49     contents = contents,
#      50     config = generate_content_config,
#      51     ):
#      52     print(chunk, end="")
# ---> 54 generate()
#
# Cell In[1], line 47, in generate()
#      18 contents = [
#      19   types.Content(
#      20     role="user",
#    (...)
#      25   )
#      26 ]
#      27 generate_content_config = types.GenerateContentConfig(
#      28   temperature = 1,
#      29   top_p = 0.95,
#    (...)
#      44   )],
#      45 )
# ---> 47 for chunk in client.models.generate_content_stream(
#      48   model = model,
#      49   contents = contents,
#      50   config = generate_content_config,
#      51   ):
#      52   print(chunk, end="")
#
# File c:\Users\pxs1101a\Downloads\Customer-Feedback-google-oauth\Customer-Feedback-google-oauth\.env\Lib\site-packages\google\genai\models.py:3818, in Models.generate_content_stream(self, model, contents, config)
#    3815 request_dict = _common.convert_to_dict(request_dict)
#    3816 request_dict = _common.encode_unserializable_types(request_dict)
# -> 3818 for response_dict in self._api_client.request_streamed(
#    3819     'post', path, request_dict, http_options
#    3820 ):
#    3822   if self._api_client.vertexai:
#    3823     response_dict = _GenerateContentResponse_from_vertex(
#    3824         self._api_client, response_dict
#    3825     )
#
# File c:\Users\pxs1101a\Downloads\Customer-Feedback-google-oauth\Customer-Feedback-google-oauth\.env\Lib\site-packages\google\genai\_api_client.py:472, in ApiClient.request_streamed(self, http_method, path, request_dict, http_options)
#     461 def request_streamed(
#     462     self,
#     463     http_method: str,
#    (...)
#     466     http_options: HttpOptionsDict = None,
#     467 ):
#     468   http_request = self._build_request(
#     469       http_method, path, request_dict, http_options
#     470   )
# --> 472   session_response = self._request(http_request, stream=True)
#     473   if http_options and 'response_payload' in http_options:
#     474     session_response.copy_to_dict(http_options['response_payload'])
#
# File c:\Users\pxs1101a\Downloads\Customer-Feedback-google-oauth\Customer-Feedback-google-oauth\.env\Lib\site-packages\google\genai\_api_client.py:372, in ApiClient._request(self, http_request, stream)
#     370 if self.vertexai and not self.api_key:
#     371   if not self._credentials:
# --> 372     self._credentials, _ = google.auth.default(
#     373         scopes=["https://www.googleapis.com/auth/cloud-platform"],
#     374     )
#     375   authed_session = AuthorizedSession(self._credentials)
#     376   authed_session.stream = stream
#
# File c:\Users\pxs1101a\Downloads\Customer-Feedback-google-oauth\Customer-Feedback-google-oauth\.env\Lib\site-packages\google\auth\_default.py:697, in default(scopes, request, quota_project_id, default_scopes)
#     689             _LOGGER.warning(
#     690                 "No project ID could be determined. Consider running "
#     691                 "`gcloud config set project` or setting the %s "
#     692                 "environment variable",
#     693                 environment_vars.PROJECT,
#     694             )
#     695         return credentials, effective_project_id
# --> 697 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.

# %%
pip install google-genai
# Out:
# Collecting google-genai
#   Downloading google_genai-0.6.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in c:\users\pxs1101a\downloads\customer-feedback-google-oauth\customer-feedback-google-oauth\.env\lib\site-packages (from google-genai) (2.37.0)
# Collecting pillow<12.0.0,>=10.0.0 (from google-genai)
#   Downloading pillow-11.1.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: pydantic<3.0.0dev,>=2.0.0 in c:\users\pxs1101a\downloads\customer-feedback-google-oauth\customer-feedback-google-oauth\.env\lib\site-packages (from google-genai) (2.10.6)
# Requirement already satisfied: requests<3.0.0dev,>=2.28.1 in c:\users\pxs1101a\downloads\customer-feedback-google-oauth\customer-feedback-google-oauth\.env\lib\site-packages (from google-genai) (2.32.3)
# Collecting websockets<15.0dev,>=13.0 (from google-genai)
#   Downloading websockets-14.2-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\pxs1101a\downloads\customer-feedback-google-oauth\customer-feedback-google-oauth\.env\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-genai) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pxs1101a\downloads\customer-feedback-google-oauth\customer-feedback-google-oauth\.env\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-genai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pxs1101a\downloads\customer-feedback-google-oauth\customer-feedback-google-oauth\.env\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-genai) (4.9)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\pxs1101a\downloads\customer-feedback-google-oauth\customer-feedback-google-oauth\.env\lib\site-packages (from pydantic<3.0.0dev,>=2.0.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\pxs1101a\downloads\customer-feedback-google-oauth\customer-feedback-google-oauth\.env\lib\site-packages (from pydantic<3.0.0dev,>=2.0.0->google-genai) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\pxs1101a\downloads\customer-feedback-google-oauth\customer-feedback-google-oauth\.env\lib\site-packages (from pydantic<3.0.0dev,>=2.0.0->google-genai) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pxs1101a\downloads\customer-feedback-google-oauth\customer-feedback-google-oauth\.env\lib\site-packages (from requests<3.0.0dev,>=2.28.1->google-genai) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pxs1101a\downloads\customer-feedback-google-oauth\customer-feedback-google-oauth\.env\lib\site-packages (from requests<3.0.0dev,>=2.28.1->google-genai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pxs1101a\downloads\customer-feedback-google-oauth\customer-feedback-google-oauth\.env\lib\site-packages (from requests<3.0.0dev,>=2.28.1->google-genai) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pxs1101a\downloads\customer-feedback-google-oauth\customer-feedback-google-oauth\.env\lib\site-packages (from requests<3.0.0dev,>=2.28.1->google-genai) (2024.12.14)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\pxs1101a\downloads\customer-feedback-google-oauth\customer-feedback-google-oauth\.env\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-genai) (0.6.1)
# Downloading google_genai-0.6.0-py3-none-any.whl (118 kB)
#    ---------------------------------------- 0.0/118.7 kB ? eta -:--:--
#    ---------------------------------------- 118.7/118.7 kB 3.5 MB/s eta 0:00:00
# Downloading pillow-11.1.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------- ----------------------------- 0.7/2.6 MB 21.8 MB/s eta 0:00:01
#    ------------------------------ --------- 2.0/2.6 MB 25.6 MB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.6 MB 18.9 MB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.6 MB 18.9 MB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.6 MB 18.9 MB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.6 MB 18.9 MB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.6 MB 18.9 MB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.6 MB 18.9 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 6.0 MB/s eta 0:00:00
# Downloading websockets-14.2-cp312-cp312-win_amd64.whl (164 kB)
#    ---------------------------------------- 0.0/164.4 kB ? eta -:--:--
#    --------------------------------------- 164.4/164.4 kB 10.3 MB/s eta 0:00:00
# Installing collected packages: websockets, pillow, google-genai
# Successfully installed google-genai-0.6.0 pillow-11.1.0 websockets-14.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import json
def transcript():
   
    # Define the URL and headers  
    url = 'https://d-api.sbdinc.com/genai/v1/google/v1beta/models/gemini-1.5-flash:generateContent'  
    headers = {  
        'Content-Type': 'application/json',  
        'api-key': '5987acef887741448e2e789ec8b624ff',
        'userId': 'Customer-Feedback-Team'  
    }
 
    # Define the payload  
    data = {  
        "contents": [  
            {  
                "parts": [  
                    {  
                        "text": f"""
                        hello
                        """  
                    }  
                ]  
            }  
        ],  
        "safetySettings": [  
            {  
                "category": "HARM_CATEGORY_DANGEROUS_CONTENT",  
                "threshold": "BLOCK_ONLY_HIGH"  
            }  
        ],  
        "generationConfig": {  
            "stopSequences": ["Title"],  
            "temperature": 1.0,  
            "maxOutputTokens": 800,  
            "topP": 0.8,  
            "topK": 10  
        }  
    }  
 
    # Make the POST request  
    response = requests.post(url, headers=headers, data=json.dumps(data))  
 
    response_json = response.json()  
    return response_json

review_summarization()
# Out:
# {'candidates': [{'content': {'parts': [{'text': 'Hello there!  How can I help you today?\n'}],
#     'role': 'model'},
#    'finishReason': 'STOP',
#    'safetyRatings': [{'category': 'HARM_CATEGORY_HATE_SPEECH',
#      'probability': 'NEGLIGIBLE'},
#     {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT',
#      'probability': 'NEGLIGIBLE'},
#     {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE'},
#     {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT',
#      'probability': 'NEGLIGIBLE'}],
#    'avgLogprobs': -0.06964096426963806}],
#  'usageMetadata': {'promptTokenCount': 5,
#   'candidatesTokenCount': 12,
#   'totalTokenCount': 17},
#  'modelVersion': 'gemini-1.5-flash'}

# %%
import requests
import json
from google import genai
from google.genai import types
from google.oauth2 import service_account

# Define the required scopes
scopes = ["https://www.googleapis.com/auth/cloud-platform"]
# Load the service account credentials
credentials = service_account.Credentials.from_service_account_file(
    'C:\\Users\\pxs1101a\\Downloads\\Customer-Feedback-google-oauth\\Customer-Feedback-google-oauth\\SVCCredentials\\marine-actor-449411-t3-9022d9539783.json',
    scopes=scopes
)

def transcript():
    # Initialize the client with credentials
    client = genai.Client(
        vertexai=True,
        project="marine-actor-449411-t3",
        location="us-central1",
        credentials=credentials  # Pass the credentials here
    )

        # Define the content
    video1 = types.Part.from_uri(
        file_uri="https://www.youtube.com/watch?v=-Fju4UajL7g",
        mime_type="video/*",
    )

    model = "gemini-2.0-flash-exp"
    contents = [
        types.Content(
        role="user",
        parts=[
            video1,
            types.Part.from_text("""Can you list all the pros and cons of the story discussed in this video.""")
        ]
        )]

    # Define the generation configuration
    generate_content_config = types.GenerateContentConfig(
        temperature=1.0,
        top_p=0.8,
        max_output_tokens=800,
        response_modalities=["TEXT"],
        safety_settings=[
            types.SafetySetting(
                category="HARM_CATEGORY_DANGEROUS_CONTENT",
                threshold="BLOCK_ONLY_HIGH"
            )
        ],
    )

    # Generate content
    for chunk in client.models.generate_content_stream(
        model="gemini-2.0-flash-exp",
        contents=contents,
        config=generate_content_config,
    ):
        print(chunk, end="")

transcript()
# Out:
# candidates=[Candidate(content=Content(parts=[Part(video_metadata=None, thought=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, inline_data=None, text='Certainly')], role='model'), citation_metadata=None, finish_message=None, token_count=None, avg_logprobs=None, finish_reason=None, grounding_metadata=None, index=None, logprobs_result=None, safety_ratings=None)] model_version='gemini-2.0-flash-exp' prompt_feedback=None usage_metadata=GenerateContentResponseUsageMetadata(cached_content_token_count=None, candidates_token_count=None, prompt_token_count=None, total_token_count=None) automatic_function_calling_history=None parsed=Nonecandidates=[Candidate(content=Content(parts=[Part(video_metadata=None, thought=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, inline_data=None, text="! Here's a breakdown of the pros and cons of the story Sammy Davis")], role='model'), citation_metadata=None, finish_message=None, token_count=None, avg_logprobs=None, finish_reason=None, grounding_metadata=None, index=None, logprobs_result=None, safety_ratings=[SafetyRating(blocked=None, category=<HarmCategory.HARM_CATEGORY_HATE_SPEECH: 'HARM_CATEGORY_HATE_SPEECH'>, probability=<HarmProbability.NEGLIGIBLE: 'NEGLIGIBLE'>, probability_score=0.0016058909, severity=<HarmSeverity.HARM_SEVERITY_NEGLIGIBLE: 'HARM_SEVERITY_NEGLIGIBLE'>, severity_score=0.09777486), SafetyRating(blocked=None, category=<HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: 'HARM_CATEGORY_DANGEROUS_CONTENT'>, probability=<HarmProbability.NEGLIGIBLE: 'NEGLIGIBLE'>, probability_score=0.00025891472, severity=<HarmSeverity.HARM_SEVERITY_NEGLIGIBLE: 'HARM_SEVERITY_NEGLIGIBLE'>, severity_score=0.06919764), SafetyRating(blocked=None, category=<HarmCategory.HARM_CATEGORY_HARASSMENT: 'HARM_CATEGORY_HARASSMENT'>, probability=<HarmProbability.NEGLIGIBLE: 'NEGLIGIBLE'>, probability_score=0.0014541197, severity=<HarmSeverity.HARM_SEVERITY_NEGLIGIBLE: 'HARM_SEVERITY_NEGLIGIBLE'>, severity_score=None), SafetyRating(blocked=None, category=<HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: 'HARM_CATEGORY_SEXUALLY_EXPLICIT'>, probability=<HarmProbability.NEGLIGIBLE: 'NEGLIGIBLE'>, probability_score=8.69754e-05, severity=<HarmSeverity.HARM_SEVERITY_NEGLIGIBLE: 'HARM_SEVERITY_NEGLIGIBLE'>, severity_score=None)])] model_version='gemini-2.0-flash-exp' prompt_feedback=None usage_metadata=None automatic_function_calling_history=None parsed=Nonecandidates=[Candidate(content=Content(parts=[Part(video_metadata=None, thought=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, inline_data=None, text=' Jr. tells in the video:\n\n**Pros:**\n\n*   **Capt')], role='model'), citation_metadata=None, finish_message=None, token_count=None, avg_logprobs=None, finish_reason=None, grounding_metadata=None, index=None, logprobs_result=None, safety_ratings=[SafetyRating(blocked=None, category=<HarmCategory.HARM_CATEGORY_HATE_SPEECH: 'HARM_CATEGORY_HATE_SPEECH'>, probability=<HarmProbability.LOW: 'LOW'>, probability_score=0.022729976, severity=<HarmSeverity.HARM_SEVERITY_NEGLIGIBLE: 'HARM_SEVERITY_NEGLIGIBLE'>, severity_score=0.16646612), SafetyRating(blocked=None, category=<HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: 'HARM_CATEGORY_DANGEROUS_CONTENT'>, probability=<HarmProbability.NEGLIGIBLE: 'NEGLIGIBLE'>, probability_score=0.00884526, severity=<HarmSeverity.HARM_SEVERITY_NEGLIGIBLE: 'HARM_SEVERITY_NEGLIGIBLE'>, severity_score=0.022262082), SafetyRating(blocked=None, category=<HarmCategory.HARM_CATEGORY_HARASSMENT: 'HARM_CATEGORY_HARASSMENT'>, probability=<HarmProbability.NEGLIGIBLE: 'NEGLIGIBLE'>, probability_score=0.0016782199, severity=<HarmSeverity.HARM_SEVERITY_NEGLIGIBLE: 'HARM_SEVERITY_NEGLIGIBLE'>, severity_score=0.044940777), SafetyRating(blocked=None, category=<HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: 'HARM_CATEGORY_SEXUALL ...

# %%
import requests
import json
from google import genai
from google.genai import types
from google.oauth2 import service_account

# Define the required scopes
scopes = ["https://www.googleapis.com/auth/cloud-platform"]
# Load the service account credentials
credentials = service_account.Credentials.from_service_account_file(
    'C:\\Users\\pxs1101a\\Downloads\\Customer-Feedback-google-oauth\\Customer-Feedback-google-oauth\\SVCCredentials\\marine-actor-449411-t3-9022d9539783.json',
    scopes=scopes
)

def transcript():
    # Initialize the client with credentials
    client = genai.Client(
        vertexai=True,
        project="marine-actor-449411-t3",
        location="us-central1",
        credentials=credentials  # Pass the credentials here
    )

    # Define the content
    video1 = types.Part.from_uri(
        file_uri="https://www.youtube.com/watch?v=-Fju4UajL7g",
        mime_type="video/*",
    )

    model = "gemini-2.0-flash-exp"
    contents = [
        types.Content(
            role="user",
            parts=[
                video1,
                types.Part.from_text("Can you list all the pros and cons of the story discussed in this video.")
            ]
        )
    ]

    # Define the generation configuration
    generate_content_config = types.GenerateContentConfig(
        temperature=1.0,
        top_p=0.8,
        max_output_tokens=800,
        response_modalities=["TEXT"],
        safety_settings=[
            types.SafetySetting(
                category="HARM_CATEGORY_DANGEROUS_CONTENT",
                threshold="BLOCK_ONLY_HIGH"
            )
        ],
    )

    # Generate content and extract text
    replies = []  # List to store extracted text
    for chunk in client.models.generate_content_stream(
        model=model,
        contents=contents,
        config=generate_content_config,
    ):
        # Assuming chunk is a dictionary-like object
        print(type(chunk))
        if 'candidates' in chunk:
            for candidate in chunk['candidates']:
                print('1 \n')
                print(candidate)
                content = candidate.get('content', {})
                parts = content.get('parts', [])
                for part in parts:
                    text = part.get('text', "")
                    if text:
                        replies.append(text)

    # Print the extracted texts
    for reply in replies:
        print(reply)

transcript()
# Out:
# <class 'google.genai.types.GenerateContentResponse'>
# <class 'google.genai.types.GenerateContentResponse'>
# <class 'google.genai.types.GenerateContentResponse'>
# <class 'google.genai.types.GenerateContentResponse'>
# <class 'google.genai.types.GenerateContentResponse'>
# <class 'google.genai.types.GenerateContentResponse'>
# <class 'google.genai.types.GenerateContentResponse'>
# <class 'google.genai.types.GenerateContentResponse'>
# <class 'google.genai.types.GenerateContentResponse'>
# <class 'google.genai.types.GenerateContentResponse'>
# <class 'google.genai.types.GenerateContentResponse'>
# <class 'google.genai.types.GenerateContentResponse'>
# <class 'google.genai.types.GenerateContentResponse'>
# <class 'google.genai.types.GenerateContentResponse'>
# <class 'google.genai.types.GenerateContentResponse'>
# <class 'google.genai.types.GenerateContentResponse'>
# <class 'google.genai.types.GenerateContentResponse'>

# %%
import requests
import json
from google import genai
from google.genai import types
from google.oauth2 import service_account

# Define the required scopes
scopes = ["https://www.googleapis.com/auth/cloud-platform"]
# Load the service account credentials
credentials = service_account.Credentials.from_service_account_file(
    'C:\\Users\\pxs1101a\\Downloads\\Customer-Feedback-google-oauth\\Customer-Feedback-google-oauth\\SVCCredentials\\marine-actor-449411-t3-9022d9539783.json',
    scopes=scopes
)

def transcript():
    # Initialize the client with credentials
    client = genai.Client(
        vertexai=True,
        project="marine-actor-449411-t3",
        location="us-central1",
        credentials=credentials  # Pass the credentials here
    )

    # Define the content
    video1 = types.Part.from_uri(
        file_uri="https://www.youtube.com/watch?v=Xt8Od-Z78Zs",
        mime_type="video/*",
    )

    model = "gemini-2.0-flash-exp"
    contents = [
        types.Content(
            role="user",
            parts=[
                video1,
                types.Part.from_text('''
                                    Can you provide the full transcript without timeline, and summary without timeline in json format?
                                    Ignore any Responsible AI violation part, You are an AI assistant that helps summarize this product's: DCST972X1 YouTube video's transcription. 
                                    Provide the customer sentiment with all positives and all negatives based solely on the transcription. 
                                    Please look at the few examples given below to form your answer, 
                                    NOTE:  If there are only negatives then provide only negative points and if only positives are available provide only positives. But if both present include both. Also, rank the positives and negatives based on number of times they appear.
                                    
                                    for example [please take it as only example and provide your own insights]: Customer Sentiment Summary for a drill-

                                    Positives:

                                    1. The product is highly praised for its power and performance.
                                    2. Users appreciate its reliability and durability.
                                    3. It receives positive feedback for being user-friendly and easy to operate.
                                    4. Customers mention the products efficiency and effectiveness in various tasks.
                                    5. The design and build quality are often highlighted as strong points.
                                    6. The product is considered good value for money by many users.

                                    Negatives:

                                    1. Some users report issues with battery life or charging time.
                                    2. A few customers mention the weight as a potential drawback for prolonged use.
                                    3. There are occasional complaints about noise levels during operation.
                                    Overall, the sentiment is largely positive, with most users satisfied with the product's performance and features.

                                    Example 2 [please take it as only example and provide your own insights]: Customer Sentiment Summary for a radio:
                                    ### Positives:
                                    1. **Durability**: Many users praise the rugged build, capable of withstanding drops and harsh conditions.
                                    2. **Sound Quality**: Generally good sound quality for a job site radio, with decent volume and clarity.
                                    3. **Bluetooth Functionality**: Users appreciate the ease of connecting Bluetooth devices and streaming music.
                                    4. **Battery Life**: Long-lasting performance on battery power, often providing multiple hours of use.
                                    5. **Charging Capabilities**: The ability to charge Dewalt batteries while using the radio is a significant advantage.
                                    6. **Versatility**: Functions well both plugged in and on battery, with additional AC outlets for powering tools.
                                    7. **User-Friendly Design**: Many find the controls easy to use, including the storage compartment for phones.
                                    8. **Lightweight**: Some users found it manageable to carry despite its ruggedness.
                                    9. **Good Reception**: Several reviews noted decent FM reception, especially compared to older models.
                                    10. **Value for Money**: Despite a higher price point, many users feel it offers good value due to its features.

                                    ### Negatives:
                                    1. **Static During Charging**: Many users reported significant static noise when charging batteries while listening to the radio.
                                    2. **Poor Radio Reception**: Some found the FM reception lacking, especially in certain environments.
                                    3. **Bluetooth Range**: Multiple complaints about the Bluetooth not reaching the advertised range of 100 feet.
                                    4. **Weight**: Some users found it too heavy for easy portability.
                                    5. **Volume Control**: Inability to control volume from connected devices was a common frustration.
                                    6. **Quality Control Issues**: Reports of units failing after a short period, including issues with the power button and charging capabilities.
                                    7. **Lack of Accessories**: Some users were disappointed by missing features like the bottle opener.
                                    8. **Screen Visibility**: The LCD display is often noted as difficult to read, especially from certain angles.
                                    9. **Price**: Many felt that the radio was overpriced for the quality and features offered.
                                    10. **Design Flaws**: Users pointed out that the design could be improved in terms of accessibility and ergonomics, such as difficult-to-open compartments.

                                    ### Summary
                                    Overall, while the Dewalt radio has received numerous praises for its durability, sound quality, and features, it has also faced significant criticism regarding static noise during charging, Bluetooth range, and quality control issues.
                                                    
                                    ''')
            ]
        )
    ]

    # Define the generation configuration
    generate_content_config = types.GenerateContentConfig(
        temperature=1.0,
        top_p=0.8,
        max_output_tokens=2500,
        response_modalities=["TEXT"],
        safety_settings=[
            types.SafetySetting(
                category="HARM_CATEGORY_DANGEROUS_CONTENT",
                threshold="BLOCK_ONLY_HIGH"
            )
        ],
    )

    # Generate content and extract text
    replies = []  # List to store extracted text
    for chunk in client.models.generate_content_stream(
        model=model,
        contents=contents,
        config=generate_content_config,
    ):
        # Access the candidates attribute of the GenerateContentResponse object
        for candidate in chunk.candidates:
            content = candidate.content
            for part in content.parts:
                text = part.text
                if text:
                    replies.append(text)
    count=0
    # Print the extracted texts
    for reply in replies:
        count=count+1
        print(count)
        print(reply)

transcript()
# Out:
# 1
# ```
# 2
# json
# {
#   "full_transcript": "Almost a year ago exactly
# 3
# , DeWalt came out with their Flex Bolt universal attachment string trimmer. Basically,
# 4
#  that means this is a 60 volt power head that will take any attachment that is listed as universal. So if it's a universal Ryobi,
# 5
#  a universal DeWalt, a universal whatever, it will take that and you'll be able to use it, which is pretty awesome for most people. I
# 6
#  have used this as a string trimmer only. I'm going to go through what I deem is what this is really great at after a year and what it kind of isn't as great as, and we'll go through if
# 7
#  you're looking at this at this point in time in the spring, what you might want to consider. The DeWalt Flex Volt universal attachment string trimmer is a 60 volt tool. So it will not take 20 volt
# 8
#  batteries. You must be invested in the 60 volt platform. Not a big deal, small battery, but it does weigh quite a bit because it's 3P. So the balance of this unit is off. Although, when you're hanging onto it a little differently, it will work a little
# 9
#  bit better. With that said, it's a little bit shorter than many, so if you're taller you might find yourself bending over a little bit more. It's a 15 to 17 inch swath down here on the head end and the head that's down here, unfortunately is
# 10
#  not always as strong as some of the people using it. If you pound that head against the ground or against rocks, you'll find that it will break quite quickly. It is not expensive to replace with the DeWalt unit and it will take many other units that are out there. It is a speed close head
# 11
#  so you can easily put the line in it. But with that said, beat it against the ground a lot and you'll find yourself with parts laying all over the place. I've got a few friends with these and it happened to them quite quickly and you just have to learn if you're going to
# 12
#  keep that head to be fairly gentle with it. The second thing that maybe is a little bit annoying to many is going to be the safety. Now this trigger is probably the most gas-like feeling trigger out there but actually it doesn't work anything like a gas trigger. It's a stepped trigger. But
# 13
#  with that said the safety on the top, you have to push this lever over and then hold this down then you can pull the trigger, otherwise it's locked out. Great for throwing it in the back of a truck or something where you're piling it around other things, horrible for actually using it in the
# 14
#  yard. Last downside to this is run time. If you're really pushing this guy, run times are about 10 minutes with a 9 amp hour battery. That is like pushing it through solid heavy grass. If you're just using it normal household stuff, you can get 20 to
# 15
# 25 minutes out of it. The reason why this one landed at my house and not in our contractor trailer or in our lawn mowing trailer is that run time. Would have to carry two batteries in order to do the same amount of work I could do with a different machine with one battery. Is that because the motor
# 16
#  is up top and we have a shaft that runs through? I don't know. There is a lot of power here. Although the RPMs are lower, low is going to be around 4,000 RPMs and high on this is going to max out about 5800. But
# 17
#  with that said, because of the 17 inch swath you really get some great line speed going and this thing cuts like a beast. And secondly, it is butter smooth. You can use this thing all day if you wanted to and it feels great, it cuts great and there is zero vibrations felt up this grip
# 18
# . This grip is purely DeWalt and once you get over that safety, you will absolutely love it. The stepped trigger, most people will get used to it, but when I say stepped trigger, it's not fully variable, it goes in different modes. And just watch my finger here and listen. As you
# 19
#  get closer to the top, it feels more variable but realistically, it's just taking different points and bumping that motor up as it goes through. That was not my finger just moving quickly through that. That was the steps as it goes through. Not a big deal, it's a little different than when if
# 20
#  you're using gas and you're trying to use the different full variable speeds, simply doesn't have it. It's just got the steps. Either way, this is one unit that I've kept the .080 line on, simply because it works great. A lot of people bump
# 21
#  up to the .095, I can see why. I do 99% of my stuff, but around home, I don't feel like I need it. And this thing really has great power. And again, the run time would suffer a little bit more if we upgraded to .09
# 22
# 5 line, so I keep it at .08. Now, kicker of what at home because of the short run time, I I can really do two to three cuts around my yard based off of one battery. I don't need to trim that much, but what ends up happening is the last cut,
# 23
#  the third one mostly, the battery is mostly dead and I'll run out of battery. So half the time, or a third, two thirds, whatever, I go out and I'll run this on low only because I'm trying to conserve battery. And around the house on low only, it does
# 24
#  awesome. It's one of the few units that I actually use the low on because I was forced to because I was kind of a dummy and didn't pull out the battery and charge it up. Overall this kit here, if you don't need super long run time and if you want some good power
# 25
#  and you have other attachments or you want to buy other attachments that are universal, an excellent buy. You will love the smoothness of it, you can easily pop a pin out here of that safety and the safety will be gone and it'll still be there but the little flip part that's annoying will be gone
# 26
# . And you will love using this trimmer. Simply a great trimmer that probably could use a little bit more run time or a little bit of, I'd hate to say put a 12 amp hour or a 15 amp hour battery on this and you'd get great run time, you would.
# 27
#  And the 12 amp hour battery isn't going to add much more weight so why not. I think that would bump it up to the realm of where some of the other models are with lesser amp hour batteries. But this unit really has a lot to offer the homeowner who really wants to have a lot of
# 28
#  power and a lot of smoothness. I mean this really reminds me of my Steel when I'm out cutting with it, it is just butter smooth and really enjoyable to use. So after one year, I would still highly recommend this unit. Be careful with the head. Now the replacing that head is 30
# 29
#  bucks, but just be careful with it. Don't beat on it and if something happens and it's not letting out line, take a look at it and just don't continue beating on it. That's my take on this guy, hope you guys enjoyed it. Please leave your comments below.
# 30
#  If you own this machine, if you have thoughts of buying it or anything else, it's always great to hear what other people have to say and a lot of people like to read that stuff and get your feedback also. We appreciate that. Give us a like on this video, subscribe to the channel if you
# 31
#  haven't already. Thank you for your time, have a great day.",
#   "summary": {
#     "overall": "The reviewer shares their experience using the DeWalt Flex Volt universal attachment string trimmer for a year. They discuss both its strengths and weaknesses, aiming to provide a balanced perspective for potential buyers
# 32
# .",
#     "positives": [
#       "The string trimmer is compatible with universal attachments.",
#       "The tool offers great power and cuts effectively.",
#       "It provides a smooth and enjoyable user experience with zero vibration.",
#       "The unit is capable of a 15-17 inch swath
# 33
# .",
#        "It has a speed close head for easy line replacement."
#     ],
#     "negatives": [
#       "The unit is shorter than many trimmers, potentially causing discomfort for taller users.",
#        "The head is not very durable and can break easily if it hits rocks or hard surfaces
# 34
# .",
#       "The safety mechanism is annoying to use for yard work.",
#        "The battery run time is relatively short, especially when used under heavy load.",
#       "It uses a stepped trigger rather than a fully variable speed."
#     ],
#      "customer_sentiment": {
#         "positives
# 35
# ": [
#            "The tool offers great power and cuts effectively.",
#           "It provides a smooth and enjoyable user experience with zero vibration.",
#             "The string trimmer is compatible with universal attachments."
#         ],
#         "negatives": [
#             "The head is not very durable and can break easily
# 36
#  if it hits rocks or hard surfaces.",
#             "The safety mechanism is annoying to use for yard work.",
#             "The battery run time is relatively short, especially when used under heavy load.",
#              "The unit is shorter than many trimmers, potentially causing discomfort for taller users.",
#             "It uses
# 37
#  a stepped trigger rather than a fully variable speed."
#         ]
#      }
#   }
# }
# ```

# %%
'candidates'
# Out:
# 'candidates'

# %%
import requests
import json

def get_transcript():
    # Define the URL and headers
    url = 'https://d-api.sbdinc.com/genai/v1/google/v1beta/models/gemini-1.5-flash:generateContent'
    headers = {
        'Content-Type': 'application/json',
        'api-key': '5987acef887741448e2e789ec8b624ff',
        'userId': 'Customer-Feedback-Team'
    }

    # Define the payload with a file URI and a text prompt
    data = {
        "contents": [
            {
                "parts": [
                    {
                        "uri": "https://www.youtube.com/watch?v=-Fju4UajL7g",
                        "mime_type": "video/*"
                    },
                    {
                        "text": "Can you list all the pros and cons of the story discussed in this video."
                    }
                ]
            }
        ],
        "safetySettings": [
            {
                "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
                "threshold": "BLOCK_ONLY_HIGH"
            }
        ],
        "generationConfig": {
            "temperature": 1.0,
            "maxOutputTokens": 800,
            "topP": 0.8,
            "topK": 10
        }
    }

    # Make the POST request
    response = requests.post(url, headers=headers, data=json.dumps(data))

    # Check for errors
    if response.status_code != 200:
        raise Exception(f"Request failed with status code {response.status_code}: {response.text}")

    # Parse the response
    response_json = response.json()
    return response_json

# Call the function and print the result
result = get_transcript()
print(result)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[8], line 54
#      51     return response_json
#      53 # Call the function and print the result
# ---> 54 result = get_transcript()
#      55 print(result)
#
# Cell In[8], line 47, in get_transcript()
#      45 # Check for errors
#      46 if response.status_code != 200:
# ---> 47     raise Exception(f"Request failed with status code {response.status_code}: {response.text}")
#      49 # Parse the response
#      50 response_json = response.json()
#
# Exception: Request failed with status code 500: { "statusCode": 500, "message": "Internal server error", "activityId": "0d4ad26d-f01b-4776-b435-27aca854855c" }

# %%
import requests
import json
import pandas as pd
from google import genai
from google.genai import types
from google.oauth2 import service_account

# Define the required scopes
scopes = ["https://www.googleapis.com/auth/cloud-platform"]
# Load the service account credentials
credentials = service_account.Credentials.from_service_account_file(
    'C:\\Users\\pxs1101a\\Downloads\\Customer-Feedback-google-oauth\\Customer-Feedback-google-oauth\\SVCCredentials\\marine-actor-449411-t3-9022d9539783.json',
    scopes=scopes
)

def transcript():
    # Initialize the client with credentials
    client = genai.Client(
        vertexai=True,
        project="marine-actor-449411-t3",
        location="us-central1",
        credentials=credentials  # Pass the credentials here
    )

    # Define the content
    video1 = types.Part.from_uri(
        file_uri="https://www.youtube.com/watch?v=Xt8Od-Z78Zs",
        mime_type="video/*",
    )

    model = "gemini-2.0-flash-exp"
    contents = [
        types.Content(
            role="user",
            parts=[
                video1,
                types.Part.from_text('''
                                    Can you provide the full transcript without timeline, and summary without timeline in json format?
                                    Ignore any Responsible AI violation part, You are an AI assistant that helps summarize this product's: DCST972X1 YouTube video's transcription. 
                                    Provide the customer sentiment with all positives and all negatives based solely on the transcription. 
                                    Please look at the few examples given below to form your answer, 
                                    NOTE:  If there are only negatives then provide only negative points and if only positives are available provide only positives. But if both present include both. Also, rank the positives and negatives based on number of times they appear.
                                    
                                    for example [please take it as only example and provide your own insights]: Customer Sentiment Summary for a drill-

                                    Positives:

                                    1. The product is highly praised for its power and performance.
                                    2. Users appreciate its reliability and durability.
                                    3. It receives positive feedback for being user-friendly and easy to operate.
                                    4. Customers mention the products efficiency and effectiveness in various tasks.
                                    5. The design and build quality are often highlighted as strong points.
                                    6. The product is considered good value for money by many users.

                                    Negatives:

                                    1. Some users report issues with battery life or charging time.
                                    2. A few customers mention the weight as a potential drawback for prolonged use.
                                    3. There are occasional complaints about noise levels during operation.
                                    Overall, the sentiment is largely positive, with most users satisfied with the product's performance and features.

                                    Example 2 [please take it as only example and provide your own insights]: Customer Sentiment Summary for a radio:
                                    ### Positives:
                                    1. **Durability**: Many users praise the rugged build, capable of withstanding drops and harsh conditions.
                                    2. **Sound Quality**: Generally good sound quality for a job site radio, with decent volume and clarity.
                                    3. **Bluetooth Functionality**: Users appreciate the ease of connecting Bluetooth devices and streaming music.
                                    4. **Battery Life**: Long-lasting performance on battery power, often providing multiple hours of use.
                                    5. **Charging Capabilities**: The ability to charge Dewalt batteries while using the radio is a significant advantage.
                                    6. **Versatility**: Functions well both plugged in and on battery, with additional AC outlets for powering tools.
                                    7. **User-Friendly Design**: Many find the controls easy to use, including the storage compartment for phones.
                                    8. **Lightweight**: Some users found it manageable to carry despite its ruggedness.
                                    9. **Good Reception**: Several reviews noted decent FM reception, especially compared to older models.
                                    10. **Value for Money**: Despite a higher price point, many users feel it offers good value due to its features.

                                    ### Negatives:
                                    1. **Static During Charging**: Many users reported significant static noise when charging batteries while listening to the radio.
                                    2. **Poor Radio Reception**: Some found the FM reception lacking, especially in certain environments.
                                    3. **Bluetooth Range**: Multiple complaints about the Bluetooth not reaching the advertised range of 100 feet.
                                    4. **Weight**: Some users found it too heavy for easy portability.
                                    5. **Volume Control**: Inability to control volume from connected devices was a common frustration.
                                    6. **Quality Control Issues**: Reports of units failing after a short period, including issues with the power button and charging capabilities.
                                    7. **Lack of Accessories**: Some users were disappointed by missing features like the bottle opener.
                                    8. **Screen Visibility**: The LCD display is often noted as difficult to read, especially from certain angles.
                                    9. **Price**: Many felt that the radio was overpriced for the quality and features offered.
                                    10. **Design Flaws**: Users pointed out that the design could be improved in terms of accessibility and ergonomics, such as difficult-to-open compartments.

                                    ### Summary
                                    Overall, while the Dewalt radio has received numerous praises for its durability, sound quality, and features, it has also faced significant criticism regarding static noise during charging, Bluetooth range, and quality control issues.
                                                    
                                    ''')
            ]
        )
    ]

    # Define the generation configuration
    generate_content_config = types.GenerateContentConfig(
        temperature=1.0,
        top_p=0.8,
        max_output_tokens=2500,
        response_modalities=["TEXT"],
        safety_settings=[
            types.SafetySetting(
                category="HARM_CATEGORY_DANGEROUS_CONTENT",
                threshold="BLOCK_ONLY_HIGH"
            )
        ],
    )

    # Generate content and extract text
    replies = []  # List to store extracted text
    for chunk in client.models.generate_content_stream(
        model=model,
        contents=contents,
        config=generate_content_config,
    ):
        # Access the candidates attribute of the GenerateContentResponse object
        for candidate in chunk.candidates:
            content = candidate.content
            for part in content.parts:
                text = part.text
                if text:
                    replies.append(text)

    # Assuming the last reply contains the JSON output
    json_output = json.loads(replies)

    # Create a DataFrame
    df = pd.DataFrame({
        "transcript": [json_output["transcript"]],
        "transcript_summary": [json_output["summary"]]
    })

    # Display the DataFrame
    print(df)

transcript()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 136
#     133     # Display the DataFrame
#     134     print(df)
# --> 136 transcript()
#
# Cell In[12], line 125, in transcript()
#     122                 replies.append(text)
#     124 # Assuming the last reply contains the JSON output
# --> 125 json_output = json.loads(replies)
#     127 # Create a DataFrame
#     128 df = pd.DataFrame({
#     129     "transcript": [json_output["transcript"]],
#     130     "transcript_summary": [json_output["summary"]]
#     131 })
#
# File C:\Python312\Lib\json\__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
# --> 339         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                         f'not {s.__class__.__name__}')
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
#
# TypeError: the JSON object must be str, bytes or bytearray, not list

# %%
import requests
import json
import pandas as pd
from google import genai
from google.genai import types
from google.oauth2 import service_account

# Define the required scopes
scopes = ["https://www.googleapis.com/auth/cloud-platform"]
# Load the service account credentials
credentials = service_account.Credentials.from_service_account_file(
    'C:\\Users\\pxs1101a\\Downloads\\Customer-Feedback-google-oauth\\Customer-Feedback-google-oauth\\SVCCredentials\\marine-actor-449411-t3-9022d9539783.json',
    scopes=scopes
)

def transcript():
    # Initialize the client with credentials
    client = genai.Client(
        vertexai=True,
        project="marine-actor-449411-t3",
        location="us-central1",
        credentials=credentials  # Pass the credentials here
    )

    # Define the content
    video1 = types.Part.from_uri(
        file_uri="https://www.youtube.com/watch?v=Xt8Od-Z78Zs",
        mime_type="video/*",
    )

    model = "gemini-2.0-flash-exp"
    contents = [
        types.Content(
            role="user",
            parts=[
                video1,
                types.Part.from_text('''
                                    Can you provide the full transcript without timeline, and summary without timeline in json format?
                                    Ignore any Responsible AI violation part, You are an AI assistant that helps summarize this product's: DCST972X1 YouTube video's transcription. 
                                    Provide the customer sentiment with all positives and all negatives based solely on the transcription. 
                                    Please look at the few examples given below to form your answer, 
                                    NOTE:  If there are only negatives then provide only negative points and if only positives are available provide only positives. But if both present include both. Also, rank the positives and negatives based on number of times they appear.
                                    
                                    for example [please take it as only example and provide your own insights]: Customer Sentiment Summary for a drill-

                                    Positives:

                                    1. The product is highly praised for its power and performance.
                                    2. Users appreciate its reliability and durability.
                                    3. It receives positive feedback for being user-friendly and easy to operate.
                                    4. Customers mention the products efficiency and effectiveness in various tasks.
                                    5. The design and build quality are often highlighted as strong points.
                                    6. The product is considered good value for money by many users.

                                    Negatives:

                                    1. Some users report issues with battery life or charging time.
                                    2. A few customers mention the weight as a potential drawback for prolonged use.
                                    3. There are occasional complaints about noise levels during operation.
                                    Overall, the sentiment is largely positive, with most users satisfied with the product's performance and features.

                                    Example 2 [please take it as only example and provide your own insights]: Customer Sentiment Summary for a radio:
                                    ### Positives:
                                    1. **Durability**: Many users praise the rugged build, capable of withstanding drops and harsh conditions.
                                    2. **Sound Quality**: Generally good sound quality for a job site radio, with decent volume and clarity.
                                    3. **Bluetooth Functionality**: Users appreciate the ease of connecting Bluetooth devices and streaming music.
                                    4. **Battery Life**: Long-lasting performance on battery power, often providing multiple hours of use.
                                    5. **Charging Capabilities**: The ability to charge Dewalt batteries while using the radio is a significant advantage.
                                    6. **Versatility**: Functions well both plugged in and on battery, with additional AC outlets for powering tools.
                                    7. **User-Friendly Design**: Many find the controls easy to use, including the storage compartment for phones.
                                    8. **Lightweight**: Some users found it manageable to carry despite its ruggedness.
                                    9. **Good Reception**: Several reviews noted decent FM reception, especially compared to older models.
                                    10. **Value for Money**: Despite a higher price point, many users feel it offers good value due to its features.

                                    ### Negatives:
                                    1. **Static During Charging**: Many users reported significant static noise when charging batteries while listening to the radio.
                                    2. **Poor Radio Reception**: Some found the FM reception lacking, especially in certain environments.
                                    3. **Bluetooth Range**: Multiple complaints about the Bluetooth not reaching the advertised range of 100 feet.
                                    4. **Weight**: Some users found it too heavy for easy portability.
                                    5. **Volume Control**: Inability to control volume from connected devices was a common frustration.
                                    6. **Quality Control Issues**: Reports of units failing after a short period, including issues with the power button and charging capabilities.
                                    7. **Lack of Accessories**: Some users were disappointed by missing features like the bottle opener.
                                    8. **Screen Visibility**: The LCD display is often noted as difficult to read, especially from certain angles.
                                    9. **Price**: Many felt that the radio was overpriced for the quality and features offered.
                                    10. **Design Flaws**: Users pointed out that the design could be improved in terms of accessibility and ergonomics, such as difficult-to-open compartments.

                                    ### Summary
                                    Overall, while the Dewalt radio has received numerous praises for its durability, sound quality, and features, it has also faced significant criticism regarding static noise during charging, Bluetooth range, and quality control issues.
                                                    
                                    ''')
            ]
        )
    ]

    # Define the generation configuration
    generate_content_config = types.GenerateContentConfig(
        temperature=1.0,
        top_p=0.8,
        max_output_tokens=2500,
        response_modalities=["TEXT"],
        safety_settings=[
            types.SafetySetting(
                category="HARM_CATEGORY_DANGEROUS_CONTENT",
                threshold="BLOCK_ONLY_HIGH"
            )
        ],
    )

    # Generate content and extract text
    replies = []  # List to store extracted text
    for chunk in client.models.generate_content_stream(
        model=model,
        contents=contents,
        config=generate_content_config,
    ):
        # Access the candidates attribute of the GenerateContentResponse object
        for candidate in chunk.candidates:
            content = candidate.content
            for part in content.parts:
                text = part.text
                if text:
                    replies.append(text)

    # Assuming the JSON output is in one of the replies
    # json_output = ''
    
    # for reply in replies:
    json_output = ''.join(map(str, replies))
    json_output = json_output.replace("json","")
    json_output = json_output.replace("```", "")
    print(json_output)
        # Attempt to parse the reply as JSON
    json_output = json.loads(json_output)


    # except json.JSONDecodeError:
    #     print('Error')  # Continue to the next reply if parsing fails

    if json_output:
        # Create a DataFrame
        df = pd.DataFrame({
            "transcript": [json_output.get("full_transcript", "")],
            "transcript_summary": [json_output.get("summary", {})]
        })

        # Display the DataFrame
        print(df)
    else:
        print("No valid JSON output found.")

transcript()
# Out:
# {
#   "full_transcript": "Almost a year ago exactly, Dewalt came out with their Flex Volt universal attachment string trimmer. Basically, that means this is a 60 volt power head that will take any attachment that is listed as universal. So if it's a universal Ryobi, a universal Dewalt, a universal whatever, it will take that and you'll be able to use it, which is pretty awesome for most people. I have used this as a string trimmer only. I'm going to go through what I deem is what this is really great as after year and what it kind of isn't as great as. And we'll go through if you're looking at this, at this point in time in the spring, what you might want to consider. The Dewalt Flex Bolt universal attachment string trimmer is a 60 volt tool, so it will not take 20 volt batteries. You must be invested in the 60 volt platform. Not a big deal. Small battery, but it does weigh quite a bit because it's three P. So the balance of this unit is off. Although when you're hanging onto it a little differently, it will work a little bit better. With that said, it's a little bit shorter than many, so if you're taller, you might find yourself bending over a little bit more. It's a 15 to 17 inch swath down here on the head end. And the head that's down here unfortunately is not always as strong as some of the people using it. If you pound that head against the ground or against rocks, you'll find that it will break quite quickly. It is not expensive to replace with the Dewalt unit and it will take many other units that are out there. It is a speed close head so you can easily put the line in it. But with that said, beat it against the ground a lot and you'll find yourself with parts laying all over the place. I've got a few friends with these and it happened to them quite quickly and you just have to learn if you're going to keep that head, to be fairly gentle with it. The second thing that maybe is a little bit annoying to many is going to be the safety. Now, this trigger is probably the most gas like feeling trigger out there, but actually it doesn't work anything like a gas trigger. It's a stepped trigger. But with that said, the safety on the top, you have to push this lever over and then hold this down then you can pull the trigger. Otherwise, it's locked out. Great for throwing it in the back of a truck or something where you're piling it around other things. Horrible for actually using it in the yard. Last downside to this is run time. If you're really pushing this guy, run times are about 10 minutes with a nine amp hour battery. That is like pushing it through solid heavy grass. If you're just using it normal household stuff, you can get 20 to 25 minutes out of it. The reason why this one landed at my house and not in our contractor trailer or in our lawn mowing trailer is that run time. We'd have to carry two batteries in order to do the same amount of work I could do with a different machine with one battery. Is that because the motor is up top and we have a shaft that runs through? I don't know. There is a lot of power here, although the RPMs are lower. Low is going to be around 4,000 RPMs and high on this is going to max out about 5,800. But with that said, because of the 17 inch swath, you really get some great line speed going and this thing cuts like a beast. And secondly, it is butter smooth. You can use this thing all day if you wanted to and it feels great, it cuts great, and there is zero vibrations felt up this grip. This grip is purely Dewalt and once you get over that safety, you will absolutely love it. The step trigger most people will get used to it, but when I say step trigger, it's not fully variable. It goes in different modes. And just watch my finger here and listen. As you get closer to the top, it feels more variable, but realistically it's just taking different points and bumping that motor up as it goes through. That was not my finger just moving quickly through that. That was the steps as it goes through. Not  ...
# }
#
#
# {
#   "summary": {
#         "overall": "The Dewalt Flex Volt universal attachment string trimmer is a 60-volt tool that accepts universal attachments. It is praised for its power and smooth operation, but also has some downsides.",
#     "positives": [
#       "Power and performance: The trimmer is described as having a lot of power and cutting like a beast.",
#       "Smooth operation: The trimmer is noted for its butter smooth operation and lack of vibrations.",
#       "Universal attachment: The power head can take any universal attachment.",
#       "Line speed: The 17-inch swath provides great line speed.",
#       "Good household use: Suitable for normal household trimming.",
#             "Great Cutting"
#     ],
#     "negatives": [
#       "Battery weight: The battery makes the unit heavy and unbalanced.",
#       "Short run time: With a 9 amp-hour battery, the run time is only 10 minutes under heavy use, and 20-25 minutes under normal use.",
#       "Short length: The trimmer is shorter than many, requiring taller users to bend over more.",
#       "Head durability: The head can break easily if it is pounded against the ground or rocks, and it needs to be handled with care.",
#       "Stepped trigger: The trigger is not fully variable and works in stepped modes rather than being like a gas trigger.",
#       "Safety mechanism: The safety mechanism on the top is described as annoying to use.",
#       "Parts Break Easily"
#     ]
#   },
#    "customer_sentiment": {
#         "positive_points": [
#             "The trimmer is described as having a lot of power and cutting like a beast.",
#             "The trimmer is noted for its butter smooth operation and lack of vibrations.",
#             "The power head can take any universal attachment.",
#             "The 17-inch swath provides great line speed.",
#             "Suitable for normal household trimming.",
#             "Great Cutting"
#          ],
#         "negative_points": [
#             "The battery makes the unit heavy and unbalanced.",
#             "With a 9 amp-hour battery, the run time is only 10 minutes under heavy use, and 20-25 minutes under normal use.",
#             "The trimmer is shorter than many, requiring taller users to bend over more.",
#             "The head can break easily if it is pounded against the ground or rocks, and it needs to be handled with care.",
#             "The trigger is not fully variable and works in stepped modes rather than being like a gas trigger.",
#             "The safety mechanism on the top is described as annoying to use.",
#             "Parts Break Easily"
#         ]
#     }
# }
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[26], line 151
#     148     else:
#     149         print("No valid JSON output found.")
# --> 151 transcript()
#
# Cell In[26], line 133, in transcript()
#     131 print(json_output)
#     132     # Attempt to parse the reply as JSON
# --> 133 json_output = json.loads(json_output)
#     136 # except json.JSONDecodeError:
#     137 #     print('Error')  # Continue to the next reply if parsing fails
#     139 if json_output:
#     140     # Create a DataFrame
#
# File C:\Python312\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File C:\Python312\Lib\json\decoder.py:340, in JSONDecoder.decode(self, s, _w)
#     338 end = _w(s, end).end()
#     339 if end != len(s):
# --> 340     raise JSONDecodeError("Extra data", s, end)
#     341 return obj
#
# JSONDecodeError: Extra data: line 7 column 1 (char 6972)

# %%
import requests
import json
import pandas as pd
from google import genai
from google.genai import types
from google.oauth2 import service_account

# Define the required scopes
scopes = ["https://www.googleapis.com/auth/cloud-platform"]
# Load the service account credentials
credentials = service_account.Credentials.from_service_account_file(
    'C:\\Users\\pxs1101a\\Downloads\\Customer-Feedback-google-oauth\\Customer-Feedback-google-oauth\\SVCCredentials\\marine-actor-449411-t3-9022d9539783.json',
    scopes=scopes
)

def transcript():
    # Initialize the client with credentials
    client = genai.Client(
        vertexai=True,
        project="marine-actor-449411-t3",
        location="us-central1",
        credentials=credentials  # Pass the credentials here
    )

    # Define the content
    video1 = types.Part.from_uri(
        file_uri="https://www.youtube.com/watch?v=Xt8Od-Z78Zs",
        mime_type="video/*",
    )

    model = "gemini-2.0-flash-exp"
    contents = [
        types.Content(
            role="user",
            parts=[
                video1,
                types.Part.from_text('''
                                    Can you provide the full transcript without timeline, and summary without timeline in json format?
                                    Ignore any Responsible AI violation part, You are an AI assistant that helps summarize this product's: DCST972X1 YouTube video's transcription. 
                                    Provide the customer sentiment with all positives and all negatives based solely on the transcription. 
                                    Please look at the few examples given below to form your answer, 
                                    NOTE:  If there are only negatives then provide only negative points and if only positives are available provide only positives. But if both present include both. Also, rank the positives and negatives based on number of times they appear.
                                    
                                    for example [please take it as only example and provide your own insights]: Customer Sentiment Summary for a drill-

                                    Positives:

                                    1. The product is highly praised for its power and performance.
                                    2. Users appreciate its reliability and durability.
                                    3. It receives positive feedback for being user-friendly and easy to operate.
                                    4. Customers mention the products efficiency and effectiveness in various tasks.
                                    5. The design and build quality are often highlighted as strong points.
                                    6. The product is considered good value for money by many users.

                                    Negatives:

                                    1. Some users report issues with battery life or charging time.
                                    2. A few customers mention the weight as a potential drawback for prolonged use.
                                    3. There are occasional complaints about noise levels during operation.
                                    Overall, the sentiment is largely positive, with most users satisfied with the product's performance and features.

                                    Example 2 [please take it as only example and provide your own insights]: Customer Sentiment Summary for a radio:
                                    ### Positives:
                                    1. **Durability**: Many users praise the rugged build, capable of withstanding drops and harsh conditions.
                                    2. **Sound Quality**: Generally good sound quality for a job site radio, with decent volume and clarity.
                                    3. **Bluetooth Functionality**: Users appreciate the ease of connecting Bluetooth devices and streaming music.
                                    4. **Battery Life**: Long-lasting performance on battery power, often providing multiple hours of use.
                                    5. **Charging Capabilities**: The ability to charge Dewalt batteries while using the radio is a significant advantage.
                                    6. **Versatility**: Functions well both plugged in and on battery, with additional AC outlets for powering tools.
                                    7. **User-Friendly Design**: Many find the controls easy to use, including the storage compartment for phones.
                                    8. **Lightweight**: Some users found it manageable to carry despite its ruggedness.
                                    9. **Good Reception**: Several reviews noted decent FM reception, especially compared to older models.
                                    10. **Value for Money**: Despite a higher price point, many users feel it offers good value due to its features.

                                    ### Negatives:
                                    1. **Static During Charging**: Many users reported significant static noise when charging batteries while listening to the radio.
                                    2. **Poor Radio Reception**: Some found the FM reception lacking, especially in certain environments.
                                    3. **Bluetooth Range**: Multiple complaints about the Bluetooth not reaching the advertised range of 100 feet.
                                    4. **Weight**: Some users found it too heavy for easy portability.
                                    5. **Volume Control**: Inability to control volume from connected devices was a common frustration.
                                    6. **Quality Control Issues**: Reports of units failing after a short period, including issues with the power button and charging capabilities.
                                    7. **Lack of Accessories**: Some users were disappointed by missing features like the bottle opener.
                                    8. **Screen Visibility**: The LCD display is often noted as difficult to read, especially from certain angles.
                                    9. **Price**: Many felt that the radio was overpriced for the quality and features offered.
                                    10. **Design Flaws**: Users pointed out that the design could be improved in terms of accessibility and ergonomics, such as difficult-to-open compartments.

                                    ### Summary
                                    Overall, while the Dewalt radio has received numerous praises for its durability, sound quality, and features, it has also faced significant criticism regarding static noise during charging, Bluetooth range, and quality control issues.
                                                    
                                    ''')
            ]
        )
    ]

    # Define the generation configuration
    generate_content_config = types.GenerateContentConfig(
        temperature=1.0,
        top_p=0.8,
        max_output_tokens=2500,
        response_modalities=["TEXT"],
        safety_settings=[
            types.SafetySetting(
                category="HARM_CATEGORY_DANGEROUS_CONTENT",
                threshold="BLOCK_ONLY_HIGH"
            )
        ],
    )

    # Generate content and extract text
    replies = []  # List to store extracted text
    for chunk in client.models.generate_content_stream(
        model=model,
        contents=contents,
        config=generate_content_config,
    ):
        # Access the candidates attribute of the GenerateContentResponse object
        for candidate in chunk.candidates:
            content = candidate.content
            for part in content.parts:
                text = part.text
                if text:
                    replies.append(text)

    # Join the replies into a single string
    json_output = ''.join(replies)

    # Remove unwanted characters
    json_output = json_output.replace("json", "").replace("```", "")

    # Ensure the JSON string is properly formatted
    json_output = json_output.strip()

    # Attempt to parse the JSON
    try:
        # Parse the JSON string into a dictionary
        parsed_json = json.loads(json_output)

        # Extract the relevant data
        full_transcript = parsed_json.get("transcript", "")
        summary = parsed_json.get("summary", {})

        # Create a DataFrame
        df = pd.DataFrame({
            "transcript": [full_transcript],
            "transcript_summary": [summary]
        })

        # Display the DataFrame
        print(df)
    except json.JSONDecodeError as e:
        print(f"Error parsing JSON: {e}")
        print(f"Problematic JSON: {json_output}")

transcript()
# Out:
# Error parsing JSON: Extra data: line 6 column 1 (char 6946)
# Problematic JSON: {
#   "transcript": "Almost a year ago exactly, DeWalt came out with their Flex Volt universal attachment string trimmer. Basically, that means this is a 60 volt power head that will take any attachment that is listed as universal. So if it's a universal Ryobi, a universal DeWalt, universal whatever, it will take that and you'll be able to use it, which is pretty awesome for most people. I have used this as a string trimmer only. I'm gonna go through what I deem as what this is really great at after year and what it kind of isn't as great as. And we'll go through if you're looking at this at this point in time in the spring what you might want to consider. The DeWalt Flex Volt universal attachment string trimmer is a 60 volt tool, so it will not take 20 volt batteries. You must be invested in the 60 volt platform. Not a big deal, small battery, but it does weigh quite a bit because it's three P. So the balance of this unit is off, although when you're hanging onto it a little differently, it will work a little bit better. With that said, it's a little bit shorter than many, so if you're taller you might find yourself bending over a little bit more. It's a 15 to 17 inch swath down here on the head end. And the head that's down here unfortunately is not always as strong as some of the people using it. If you pound that head against the ground or against rocks, you'll find that it will break quite quickly. It is not expensive to replace with the DeWalt unit, and it will take many other units that are out there. It is a speed close head, so you can easily put the line in it. But with that said, beat it against the ground a lot and you'll find yourself with parts laying all over the place. I've got a few friends with these and it happened to them quite quickly, and you just have to learn if you're gonna keep that head, to be fairly gentle with it. The second thing that maybe is a little bit annoying to many is going to be this safety. Now this trigger is probably the most gas like feeling trigger out there, but actually it doesn't work anything like a gas trigger. It's a stepped trigger, but with that said the safety on the top, you have to push this lever over and then hold this down, then you can pull the trigger, otherwise it's locked out. Great for throwing it in the back of a truck or something where you're piling it around other things, horrible for actually using it in the yard. Last downside to this is run time. If you're really pushing this guy, run times are about 10 minutes with a 9 amp hour battery. That is like pushing it through solid heavy grass. If you're just using it in normal household stuff you can get 20 to 25 minutes out of it. The reason why this one landed at my house and not in our contractor trailer or in our lawn mowing trailer is that run time. Would have to carry two batteries in order to do the same amount of work I could do with a different machine with one battery. Is that because the motor is up top and we have a shaft that runs through, I don't know. There is a lot of power here, although the RPMs are lower. Low is going to be around 4,000 RPMs and high on this is going to max out about 5,800. But with that said, because of the 17 inch swath, you really get some great line speed going and this thing cuts like a beast. And secondly, it is butter smooth. You can use this thing all day if you wanted to and it feels great. It cuts great and there is zero vibrations felt up this grip. This grip is purely DeWalt and once you get over that safety, you will absolutely love it. The step trigger, most people will get used to it, but when I say step trigger, it's not fully variable. It goes in different modes and just watch my finger here and listen. As you get closer to the top, it feels more variable, but realistically it's just taking different points and bumping that motor up as it goes through. That was not my finger just moving quickly through that, that was the steps as it goes through. Not a big deal. It' ...
# }
#
#
# {
#   "summary": "The DeWalt Flex Volt universal attachment string trimmer is a 60 volt tool that can use any universal attachment. While it's powerful and smooth, it's shorter than some other models, and it doesn't accept 20-volt batteries. The balance of the unit is off but can be managed when you're hanging onto it. The head can break quickly if used aggressively against the ground or rocks. The trigger is described as gas-like but is actually a stepped trigger. It is very smooth with little to no vibrations. The safety is considered annoying but is useful for transport. The run time is approximately 10 minutes when pushing it hard and 20 to 25 minutes with normal use, using a 9-amp hour battery. A 12 amp hour battery would improve runtime without adding much more weight. The unit has a 15 to 17 inch swath and RPMs of 4000 to 5800. Overall, it's recommended for homeowners looking for power and smoothness. The reviewer suggests being gentle with the head and considering a higher amp battery for longer runtime. ",
#    "customer_sentiment": {
#     "positives": [
#       {
#         "point": "The unit is powerful and smooth to use.",
#         "rank": 1
#       },
#         {
#         "point":"It's a universal attachment tool that can take various universal attachments.",
#           "rank": 2
#         },
#          {
#           "point":"It is easy to add the line.",
#            "rank": 3
#         },
#          {
#         "point":"The grip is comfortable with zero vibrations.",
#            "rank": 4
#         }
#     ],
#     "negatives": [
#       {
#         "point": "The head can break quickly if used aggressively.",
#         "rank": 1
#       },
#         {
#         "point":"The balance of the unit is off.",
#           "rank": 2
#         },
#          {
#           "point":"The safety can be annoying when in use.",
#            "rank": 3
#         },
#          {
#           "point":"The runtime can be as low as 10 minutes.",
#             "rank": 4
#         },
#         {
#           "point": "It is shorter than many other models.",
#           "rank": 5
#         },
#          {
#           "point": "It is a stepped trigger and not a fully variable speed.",
#             "rank": 6
#         }
#     ]
#   }
# }

# %%
import requests
import json
import pandas as pd
from google import genai
from google.genai import types
from google.oauth2 import service_account

# Define the required scopes
scopes = ["https://www.googleapis.com/auth/cloud-platform"]
# Load the service account credentials
credentials = service_account.Credentials.from_service_account_file(
    'C:\\Users\\pxs1101a\\Downloads\\Customer-Feedback-google-oauth\\Customer-Feedback-google-oauth\\SVCCredentials\\marine-actor-449411-t3-9022d9539783.json',
    scopes=scopes
)

def transcript():
    # Initialize the client with credentials
    client = genai.Client(
        vertexai=True,
        project="marine-actor-449411-t3",
        location="us-central1",
        credentials=credentials  # Pass the credentials here
    )

    # Define the content
    video1 = types.Part.from_uri(
        file_uri="https://www.youtube.com/watch?v=Xt8Od-Z78Zs",
        mime_type="video/*",
    )

    model = "gemini-2.0-flash-exp"
    contents = [
        types.Content(
            role="user",
            parts=[
                video1,
                types.Part.from_text('''
                                    Can you provide the full transcript without timeline, and Customer Sentiment Summary without timeline in json format?
                                    Ignore any Responsible AI violation part, You are an AI assistant that helps summarize this product's: DCST972X1 YouTube video's transcription. 
                                    Provide the customer sentiment with all positives and all negatives based solely on the transcription. 
                                    Please look at the few examples given below to form your answer, 
                                    NOTE:  If there are only negatives then provide only negative points and if only positives are available provide only positives. But if both present include both. Also, rank the positives and negatives based on number of times they appear.
                                    
                                    for example [please take it as only example and provide your own insights]: 
                                    
                                        {
                                        "transcript": "Almost a year ago exactly, Dewalt came out with their Flex Bolt Universal attachment string trimmer. Basically, that means this is a 60-volt power head that will take any attachment that is listed as universal. So if it's a universal Ryobi, a universal Dewalt, a universal whatever, it will take that and you'll be able to use it, which is pretty awesome for most people. I have used this as a string trimmer only. I'm going to go through what I deem as what this is really great as after a year, and what it kind of isn't as great as. And we'll go through if you're looking at this at this point in time in the spring, what you might want to consider.\n\nThe Dewalt Flexvolt Universal attachment string trimmer is a 60-volt tool, so it will not take 20-volt batteries. You must be invested in the 60-volt platform. Not a big deal. Small battery, but it does weigh quite a bit because it's 3P. So the balance of this unit is off, although when you're hanging onto it a little differently, it will work a little bit better. With that said, it's a little bit shorter than many, so if you're taller, you might find yourself bending over a little bit more. It's a 15 to 17-inch swath down here on the head end. And the head that's down here, unfortunately, is not always as strong as some of the people using it. If you pound that head against the ground or against rocks, you'll find that it will break quite quickly. It is not expensive to replace with the Dewalt unit and it will take many other units that are out there. It is a speed close head, so you can easily put the line in it, but with that said, beat it against the ground a lot and you'll find yourself with parts laying all over the place. I've got a few friends with these and it happened to them quite quickly and you just have to learn if you're going to keep that head to be fairly gentle with it.\n\nThe second thing that maybe is a little bit annoying to many is going to be the safety. Now, this trigger is probably the most gas-like feeling trigger out there, but actually, it doesn't work anything like a gas trigger. It's a stepped trigger. But with that said, the safety on the top, you have to push this lever over and then hold this down, then you can pull the trigger. Otherwise, it's locked out. Great for throwing it in the back of a truck or something where you're piling it around other things, horrible for actually using it in the yard. Last downside to this is runtime. If you're really pushing this guy, runtimes are about 10 minutes with a 9 amp hour battery. That is like pushing it through solid, heavy grass. If you're just using it in normal household stuff, you can get 20 to 25 minutes out of it.\n\nThe reason why this one landed at my house and not in our contractor trailer or in our lawn mowing trailer is that runtime. Would have to carry two batteries in order to do the same amount of work I could do with a different machine with one battery. Is that because the motor is up top and we have a shaft that runs through? I don't know. There is a lot of power here, although the RPMs are lower. Low is going to be around 4,000 RPMs and high on this is going to max out about 5,800. But with that said, because of the 17-inch swath, you really get some great line speed going and this thing cuts like a beast.\n\nAnd secondly, it is butter smooth. You can use this thing all day if you wanted to and it feels great, it cuts great and there is zero vibrations felt up this grip. This grip is purely Dewalt and once you get over that safety, you will absolutely love it. The stepped trigger most people will get used to it, but when I say stepped trigger, it's not fully variable. It goes in different modes and just watch my finger here and listen.\n\nAs you get closer to the top, it feels more variable, but realistically it's just taking different points and bumping that motor up as it goes. That was not my finger just moving quickly through that. That was the steps as it goes through. Not a big deal. It's a little different than when if you're using gas and you're trying to use the different full variable speeds, it simply doesn't have it. It's just got the steps. Either way, this is one unit that I've kept the 0.080 line on, simply because it works great. A lot of people bump up to the 0.095, I can see why. I do on 99% of my stuff, but around home, I don't feel like I need it and this thing really has great power. And again, the runtime would suffer a little bit more if we upgraded to 0.095 line, so I keep it at 0.08.\n\nNow, kicker of what at home because of the short runtime, I can really do two to three cuts around my yard based off of one battery. I don't need to trim that much, but what ends up happening is the last cut, the third one mostly, the battery is mostly dead and I'll run out of battery. So half the time or a third, two-thirds, whatever, I go out and I'll run this on low only because I'm trying to conserve battery. And around the house on low only, it does awesome.\n\nIt's one of the few units that I actually use the low on because I was forced to because I was kind of a dummy and didn't pull out the battery and charge it up. Overall, this kit here, if you don't need super long runtime and if you want some good power and you have other attachments or you want to buy other attachments that are universal, an excellent buy. You will love the smoothness of it. You can easily pop a pin out here of that safety and the safety will be gone and it'll still be there, but the little flip part that's annoying will be gone and you will love using this trimmer. It's simply a great trimmer that probably could use a little bit more runtime or a little bit of uh I'd hate to say put a 12 amp hour or 15 amp hour battery on this and you'd get great runtime. You would. And the 12 amp hour battery isn't going to add much more weight, so why not? I think that would bump it up to the realm of where some of the other models are with lesser amp hour batteries.\nBut this unit really has a lot to offer the homeowner who really wants to have a lot of power and a lot of smoothness. I mean, this really reminds me of my steel when I'm out cutting with it is just butter smooth and really enjoyable to use. So after one year, I would still highly recommend this unit. Be careful with the head. Now the replacing that head's 30 bucks, but just be careful with it, don't beat on it and if something happens and it's not letting out line, take a look at it and just don't continue beating on it.\nThat's my take on this guy. Hope you guys enjoyed it. Please leave your comments below if you own this machine, if you have thoughts of buying it or anything else. It's always great to hear what other people have to say and a lot of people like to read that stuff and get your feedback also. We appreciate that. Give us a like in this video, subscribe to the channel if you haven't already. Thank you for your time. Have a great day.",
                                        "customer_sentiment_summary": {
                                            "positives": [
                                            "The product is highly praised for its power and performance.",
                                            "Users appreciate its reliability and durability.",
                                            "It receives positive feedback for being user-friendly and easy to operate.",
                                            "Customers mention the products efficiency and effectiveness in various tasks.",
                                            "The design and build quality are often highlighted as strong points.",
                                            "The product is considered good value for money by many users."
                                            ],
                                            "negatives": [
                                            "Some users report issues with battery life or charging time.",
                                            "A few customers mention the weight as a potential drawback for prolonged use.",
                                            "There are occasional complaints about noise levels during operation."
                                            ],
                                            "overall": "Overall, the sentiment is largely positive, with most users satisfied with the product's performance and features."
                                        }
                                        }


                                    ''')
            ]
        )
    ]

    # Define the generation configuration
    generate_content_config = types.GenerateContentConfig(
        temperature=1.0,
        top_p=0.8,
        max_output_tokens=2500,
        response_modalities=["TEXT"],
        safety_settings=[
            types.SafetySetting(
                category="HARM_CATEGORY_DANGEROUS_CONTENT",
                threshold="BLOCK_ONLY_HIGH"
            )
        ],
    )

    # Generate content and extract text
    replies = []  # List to store extracted text
    for chunk in client.models.generate_content_stream(
        model=model,
        contents=contents,
        config=generate_content_config,
    ):
        # Access the candidates attribute of the GenerateContentResponse object
        for candidate in chunk.candidates:
            content = candidate.content
            for part in content.parts:
                text = part.text
                if text:
                    replies.append(text)

    # Join the replies into a single string
    json_output = ''.join(replies)

    # Remove unwanted characters
    json_output = json_output.replace("json", "").replace("```", "")

    # Ensure the JSON string is properly formatted
    json_output = json_output.strip()

    # Parse each JSON object
    parsed_jsons = []

    # print('json output: ' +json_output)

    parsed_jsons.append(json.loads(json_output))

    # print('json objects: ' +json_objects)
    # Parse each JSON object
    # parsed_jsons = []

    # for obj in json_objects:
    #     try:
    #         print("Attempting to parse JSON object:")
    #         print(obj)  # Print the JSON object for debugging
    #         parsed_jsons.append(json.loads(obj))
    #     except json.JSONDecodeError as e:
    #         print(f"Error parsing JSON: {e}")
    #         print(f"Problematic JSON: {obj[:100]}...")  # Print the first 100 characters for context

    # Extract the relevant data
    # if len(parsed_jsons) >= 2:
    full_transcript = parsed_jsons[0].get("transcript", "")
    summary = parsed_jsons[0].get("customer_sentiment_summary", {})
    # sentiment = parsed_jsons[0].get("customer_sentiment", {})

    # Create a DataFrame
    df = pd.DataFrame({
        "transcript": [full_transcript],
        "transcript_summary": [summary],
        # "customer_sentiment": [sentiment]
    })
    return df
    # Display the DataFrame
    # print(df['transcript'])
    # else:
        # print("Not enough JSON objects found.")

df=transcript()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[46], line 148
#     142     return df
#     143     # Display the DataFrame
#     144     # print(df['transcript'])
#     145     # else:
#     146         # print("Not enough JSON objects found.")
# --> 148 df=transcript()
#
# Cell In[46], line 115, in transcript()
#     111 parsed_jsons = []
#     113 # print('json output: ' +json_output)
# --> 115 parsed_jsons.append(json.loads(json_output))
#     117 # print('json objects: ' +json_objects)
#     118 # Parse each JSON object
#     119 # parsed_jsons = []
#    (...)
#     130 # Extract the relevant data
#     131 # if len(parsed_jsons) >= 2:
#     132 full_transcript = parsed_jsons[0].get("transcript", "")
#
# File C:\Python312\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File C:\Python312\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File C:\Python312\Lib\json\decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Invalid control character at: line 2 column 670 (char 671)

# %%
df

# %%
json.loads(parsed_jsons[0].get("customer_sentiment", {}))

# %%
df.to_csv('transcript.csv')

# %% [markdown]
# --------------------try---------------------------

# %%
import requests
import json
import pandas as pd
from google import genai
from google.genai import types
from google.oauth2 import service_account

# Define the required scopes
scopes = ["https://www.googleapis.com/auth/cloud-platform"]
# Load the service account credentials
credentials = service_account.Credentials.from_service_account_file(
    'C:\\Users\\pxs1101a\\Downloads\\Customer-Feedback-google-oauth\\Customer-Feedback-google-oauth\\SVCCredentials\\marine-actor-449411-t3-9022d9539783.json',
    scopes=scopes)


# Initialize the client with credentials
client = genai.Client(
    vertexai=True,
    project="marine-actor-449411-t3",
    location="us-central1",
    credentials=credentials  # Pass the credentials here
)

# Define the content
video1 = types.Part.from_uri(
    file_uri="https://www.youtube.com/watch?v=Xt8Od-Z78Zs",
    mime_type="video/*",
)

model = "gemini-2.0-flash-exp"
contents = [
    types.Content(
        role="user",
        parts=[
            video1,
            types.Part.from_text('''
                                Can you provide the full transcript without timeline, and Customer Sentiment Summary without timeline in json format?
                                Ignore any Responsible AI violation part, You are an AI assistant that helps summarize this product's: DCST972X1 YouTube video's transcription. 
                                Provide the customer sentiment with all positives and all negatives based solely on the transcription. 
                                Please look at the few examples given below to form your answer, 
                                NOTE:  If there are only negatives then provide only negative points and if only positives are available provide only positives. But if both present include both. Also, rank the positives and negatives based on number of times they appear.
                                
                                for example [please take it as only example and provide your own insights]: 
                                 
                                    {
                                    "transcript": "Almost a year ago exactly, Dewalt came out with their Flex Bolt Universal attachment string trimmer. Basically, that means this is a 60-volt power head that will take any attachment that is listed as universal. So if it's a universal Ryobi, a universal Dewalt, a universal whatever, it will take that and you'll be able to use it, which is pretty awesome for most people. I have used this as a string trimmer only. I'm going to go through what I deem as what this is really great as after a year, and what it kind of isn't as great as. And we'll go through if you're looking at this at this point in time in the spring, what you might want to consider.\n\nThe Dewalt Flexvolt Universal attachment string trimmer is a 60-volt tool, so it will not take 20-volt batteries. You must be invested in the 60-volt platform. Not a big deal. Small battery, but it does weigh quite a bit because it's 3P. So the balance of this unit is off, although when you're hanging onto it a little differently, it will work a little bit better. With that said, it's a little bit shorter than many, so if you're taller, you might find yourself bending over a little bit more. It's a 15 to 17-inch swath down here on the head end. And the head that's down here, unfortunately, is not always as strong as some of the people using it. If you pound that head against the ground or against rocks, you'll find that it will break quite quickly. It is not expensive to replace with the Dewalt unit and it will take many other units that are out there. It is a speed close head, so you can easily put the line in it, but with that said, beat it against the ground a lot and you'll find yourself with parts laying all over the place. I've got a few friends with these and it happened to them quite quickly and you just have to learn if you're going to keep that head to be fairly gentle with it.\n\nThe second thing that maybe is a little bit annoying to many is going to be the safety. Now, this trigger is probably the most gas-like feeling trigger out there, but actually, it doesn't work anything like a gas trigger. It's a stepped trigger. But with that said, the safety on the top, you have to push this lever over and then hold this down, then you can pull the trigger. Otherwise, it's locked out. Great for throwing it in the back of a truck or something where you're piling it around other things, horrible for actually using it in the yard. Last downside to this is runtime. If you're really pushing this guy, runtimes are about 10 minutes with a 9 amp hour battery. That is like pushing it through solid, heavy grass. If you're just using it in normal household stuff, you can get 20 to 25 minutes out of it.\n\nThe reason why this one landed at my house and not in our contractor trailer or in our lawn mowing trailer is that runtime. Would have to carry two batteries in order to do the same amount of work I could do with a different machine with one battery. Is that because the motor is up top and we have a shaft that runs through? I don't know. There is a lot of power here, although the RPMs are lower. Low is going to be around 4,000 RPMs and high on this is going to max out about 5,800. But with that said, because of the 17-inch swath, you really get some great line speed going and this thing cuts like a beast.\n\nAnd secondly, it is butter smooth. You can use this thing all day if you wanted to and it feels great, it cuts great and there is zero vibrations felt up this grip. This grip is purely Dewalt and once you get over that safety, you will absolutely love it. The stepped trigger most people will get used to it, but when I say stepped trigger, it's not fully variable. It goes in different modes and just watch my finger here and listen.\n\nAs you get closer to the top, it feels more variable, but realistically it's just taking different points and bumping that motor up as it goes. That was not my finger just moving quickly through that. That was the steps as it goes through. Not a big deal. It's a little different than when if you're using gas and you're trying to use the different full variable speeds, it simply doesn't have it. It's just got the steps. Either way, this is one unit that I've kept the 0.080 line on, simply because it works great. A lot of people bump up to the 0.095, I can see why. I do on 99% of my stuff, but around home, I don't feel like I need it and this thing really has great power. And again, the runtime would suffer a little bit more if we upgraded to 0.095 line, so I keep it at 0.08.\n\nNow, kicker of what at home because of the short runtime, I can really do two to three cuts around my yard based off of one battery. I don't need to trim that much, but what ends up happening is the last cut, the third one mostly, the battery is mostly dead and I'll run out of battery. So half the time or a third, two-thirds, whatever, I go out and I'll run this on low only because I'm trying to conserve battery. And around the house on low only, it does awesome.\n\nIt's one of the few units that I actually use the low on because I was forced to because I was kind of a dummy and didn't pull out the battery and charge it up. Overall, this kit here, if you don't need super long runtime and if you want some good power and you have other attachments or you want to buy other attachments that are universal, an excellent buy. You will love the smoothness of it. You can easily pop a pin out here of that safety and the safety will be gone and it'll still be there, but the little flip part that's annoying will be gone and you will love using this trimmer. It's simply a great trimmer that probably could use a little bit more runtime or a little bit of uh I'd hate to say put a 12 amp hour or 15 amp hour battery on this and you'd get great runtime. You would. And the 12 amp hour battery isn't going to add much more weight, so why not? I think that would bump it up to the realm of where some of the other models are with lesser amp hour batteries.\nBut this unit really has a lot to offer the homeowner who really wants to have a lot of power and a lot of smoothness. I mean, this really reminds me of my steel when I'm out cutting with it is just butter smooth and really enjoyable to use. So after one year, I would still highly recommend this unit. Be careful with the head. Now the replacing that head's 30 bucks, but just be careful with it, don't beat on it and if something happens and it's not letting out line, take a look at it and just don't continue beating on it.\nThat's my take on this guy. Hope you guys enjoyed it. Please leave your comments below if you own this machine, if you have thoughts of buying it or anything else. It's always great to hear what other people have to say and a lot of people like to read that stuff and get your feedback also. We appreciate that. Give us a like in this video, subscribe to the channel if you haven't already. Thank you for your time. Have a great day.",
                                    "customer_sentiment_summary": {
                                        "positives": [
                                        "The product is highly praised for its power and performance.",
                                        "Users appreciate its reliability and durability.",
                                        "It receives positive feedback for being user-friendly and easy to operate.",
                                        "Customers mention the products efficiency and effectiveness in various tasks.",
                                        "The design and build quality are often highlighted as strong points.",
                                        "The product is considered good value for money by many users."
                                        ],
                                        "negatives": [
                                        "Some users report issues with battery life or charging time.",
                                        "A few customers mention the weight as a potential drawback for prolonged use.",
                                        "There are occasional complaints about noise levels during operation."
                                        ],
                                        "overall": "Overall, the sentiment is largely positive, with most users satisfied with the product's performance and features."
                                    }
                                    }


                                ''')
        ]
    )
]

# Define the generation configuration
generate_content_config = types.GenerateContentConfig(
    temperature=1.0,
    top_p=0.8,
    max_output_tokens=2500,
    response_modalities=["TEXT"],
    safety_settings=[
        types.SafetySetting(
            category="HARM_CATEGORY_DANGEROUS_CONTENT",
            threshold="BLOCK_ONLY_HIGH"
        )
    ],
)

# Generate content and extract text
replies = []  # List to store extracted text
for chunk in client.models.generate_content_stream(
    model=model,
    contents=contents,
    config=generate_content_config,
):
    # Access the candidates attribute of the GenerateContentResponse object
    for candidate in chunk.candidates:
        content = candidate.content
        for part in content.parts:
            text = part.text
            if text:
                replies.append(text)

# Join the replies into a single string
json_output = ''.join(replies)

# Remove unwanted characters
json_output = json_output.replace("json", "").replace("```", "")

# Ensure the JSON string is properly formatted
json_output = json_output.strip()

# Parse each JSON object
parsed_jsons = []

# print('json output: ' +json_output)

parsed_jsons.append(json.loads(json_output))


full_transcript = parsed_jsons[0].get("transcript", "")
summary = parsed_jsons[0].get("customer_sentiment_summary", {})

df = pd.DataFrame({
    "transcript": [full_transcript],
    "transcript_summary": [summary],
    # "customer_sentiment": [sentiment]
})

print(df)

st.write(df)
# Out:
#                                           transcript  \
# 0  Almost a year ago exactly, Dewalt came out wit...
#
#                                   transcript_summary
# 0  {'positives': ['The product is butter smooth a...

# %%
df
# Out:
#                                           transcript  \
# 0  Almost a year ago exactly, Dewalt came out wit...
#
#                                   transcript_summary
# 0  {'positives': ['The product is butter smooth a...

# %%
# Initialize the client with credentials
client = genai.Client(
    vertexai=True,
    project="marine-actor-449411-t3",
    location="us-central1",
    credentials=credentials  # Pass the credentials here
)

# Define the content
video1 = types.Part.from_uri(
    file_uri="https://www.youtube.com/watch?v=Xt8Od-Z78Zs",
    mime_type="video/*",
)

model = "gemini-2.0-flash-exp"
contents = [
    types.Content(
        role="user",
        parts=[
            video1,
            types.Part.from_text('''
                                Can you provide the full comments and Customer Sentiment Summary without timeline in json format?
                                Ignore any Responsible AI violation part, You are an AI assistant that helps summarize this product's: DCST972X1 YouTube video's transcription. 
                                Provide the customer sentiment with all positives and all negatives based solely on the transcription. 
                                Please look at the few examples given below to form your answer, 
                                NOTE:  If there are only negatives then provide only negative points and if only positives are available provide only positives. But if both present include both. Also, rank the positives and negatives based on number of times they appear.
                                
                                for example [please take it as only example and provide your own insights]: 
                                 
                                    {
                                    "comments": [list of comments]
                                    "customer_sentiment_summary": {
                                        "positives": [
                                        "The product is highly praised for its power and performance.",
                                        "Users appreciate its reliability and durability.",
                                        "It receives positive feedback for being user-friendly and easy to operate.",
                                        "Customers mention the products efficiency and effectiveness in various tasks.",
                                        "The design and build quality are often highlighted as strong points.",
                                        "The product is considered good value for money by many users."
                                        ],
                                        "negatives": [
                                        "Some users report issues with battery life or charging time.",
                                        "A few customers mention the weight as a potential drawback for prolonged use.",
                                        "There are occasional complaints about noise levels during operation."
                                        ],
                                        "overall": "Overall, the sentiment is largely positive, with most users satisfied with the product's performance and features."
                                    }
                                    }


                                ''')
        ]
    )
]

# Define the generation configuration
generate_content_config = types.GenerateContentConfig(
    temperature=1.0,
    top_p=0.8,
    max_output_tokens=2500,
    response_modalities=["TEXT"],
    safety_settings=[
        types.SafetySetting(
            category="HARM_CATEGORY_DANGEROUS_CONTENT",
            threshold="BLOCK_ONLY_HIGH"
        )
    ],
)

# Generate content and extract text
replies = []  # List to store extracted text
for chunk in client.models.generate_content_stream(
    model=model,
    contents=contents,
    config=generate_content_config,
):
    # Access the candidates attribute of the GenerateContentResponse object
    for candidate in chunk.candidates:
        content = candidate.content
        for part in content.parts:
            text = part.text
            if text:
                replies.append(text)

# Join the replies into a single string
json_output = ''.join(replies)

# %%
print(json_output)
# Out:
# ```json
# {
#   "comments": [],
#   "customer_sentiment_summary": {
#     "positives": [
#       "Smoothness of use is highly appreciated.",
#       "Good power and cutting ability are noted.",
#       "Universal attachment compatibility is a significant advantage."
#     ],
#     "negatives": [
#       "Short runtime, especially under heavy use, is a drawback.",
#       "The head of the string trimmer is prone to breaking if used aggressively.",
#       "The balance of the unit is off.",
#       "Safety mechanism is annoying to use.",
#       "Step trigger is not fully variable."
#     ],
#     "overall": "The DeWalt FlexVolt Universal Attachment String Trimmer is powerful and smooth to use, but suffers from short runtime and a fragile head. Its universal attachment compatibility is a significant plus, though the safety mechanism and stepped trigger may be annoying."
#   }
# }
# ```

# %%
# parsed_jsons[0].get("transcript", "")

# %%
df = pd.DataFrame({
    "transcript": [full_transcript],
    "transcript_summary": [summary],
    # "customer_sentiment": [sentiment]
})

# %%
a=df['transcript_summary'].to_json()

# %%
a
# Out:
# '{"0":{"positives":["Butter smooth, enjoyable to use (4 mentions)","Cuts great (2 mentions)","Great power (2 mentions)","It will take any attachment that is listed as universal","Awesome for most people","It is not expensive to replace with the Dewalt unit and it will take many other units that are out there","Speed close head, so you can easily put the line in it","Great for throwing it in the back of a truck or something where you\'re piling it around other things","Zero vibrations felt up this grip","Recommend this unit","It works great"],"negatives":["Short runtime (4 mentions)","Be careful with the head (3 mentions)","Weight quite a bit because it\'s 3P","Balance of this unit is off","Shorter than many, so if you\'re taller, you might find yourself bending over a little bit more","Not always as strong as some of the people using it. If you pound that head against the ground or against rocks, you\'ll find that it will break quite quickly","Horrible for actually using it in the yard","Annoying is going to be the safety","Stepped trigger, it\'s not fully variable"]}}'

# %%
# str(parsed_jsons[0].get("customer_sentiment_summary", {})).replace("    ", "")
# Out:
# '{\'positives\': [\'Takes any attachment that is listed as universal\', \'Pretty awesome for most people\', \'Cuts like a beast\', \'Butter smooth\', \'Zero vibrations felt up this grip\', \'Highly recommend this unit\', \'Works great\', \'Great power\', \'Really enjoyable to use\', \'Awesome (around the house on low only)\'], \'negatives\': [\'Balance of this unit is off\', \'Shorter than many\', \'The head down here, unfortunately, is not always as strong as some of the people using it\', \'The safety on the top, you have to push this lever over and then hold this down, then you can pull the trigger\', \'Runtime (if really pushing the trimmer, runtimes are about 10 minutes)\', \'Horrible for actually using it in the yard (safety)\'], \'overall\': "Overall, the sentiment is largely positive, with most users satisfied with the product\'s performance and features."}'

# %%
# customer=[]
# customer.append(json.loads(str(parsed_jsons[0].get("customer_sentiment_summary", {}))))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[43], line 2
#       1 customer=[]
# ----> 2 customer.append(json.loads(str(parsed_jsons[0].get("customer_sentiment_summary", {}))))
#
# File C:\Python312\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File C:\Python312\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File C:\Python312\Lib\json\decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)

# %%
json.loads(json_output)
# Out:
# {'transcript': "Almost a year ago exactly, DeWalt came out with their Flex Volt Universal Attachment String Trimmer. Basically, that means this is a 60-volt power head that will take any attachment that is listed as universal. So, if it's a universal Ryobi, a universal DeWalt, a universal whatever, it will take that and you'll be able to use it, which is pretty awesome for most people. I have used this as a string trimmer only. I'm going to go through what I deem is what this is really great as after a year and what it kind of isn't as great as. And we'll go through if you're looking at this at this point in time in the spring, what you might want to consider. The DeWalt Flex Volt Universal Attachment String Trimmer is a 60-volt tool, so it will not take 20-volt batteries. You must be invested in the 60-volt platform. Not a big deal. Small battery, but it does weigh quite a bit because it's 3p. So, the balance of this unit is off. Although when you're hanging onto it a little differently, it will work a little bit better. With that said, it's a little bit shorter than many, so if you're taller, you might find yourself bending over a little bit more. It's a 15 to 17-inch swath down here on the head end. And the head that's down here, unfortunately, is not always as strong as some of the people using it. If you pound that head against the ground or against rocks, you'll find that it will break quite quickly. It is not expensive to replace with the DeWalt unit, and it will take many other units that are out there. It is a speed close head, so you can easily put the line in it, but with that said, beated against the ground a lot, and you'll find yourself with parts laying all over the place. I've got a few friends with these and it happened to them quite quickly and you just have to learn if you're going to keep that head to be fairly gentle with it. The second thing that maybe is a little bit annoying to many is going to be this safety. Now this trigger is probably the most gas-like feeling trigger out there, but actually it doesn't work anything like a gas trigger. It's a stepped trigger. But with that said, the safety on the top, you have to push this lever over and then hold this down, then you can pull the trigger. Otherwise, it's locked out. Great for throwing it in the back of a truck or something where you're piling it around other things, horrible for actually using it in the yard. Last downside to this is runtime. If you're really pushing this guy, runtimes are about 10 minutes with a 9 amp hour battery. That is like pushing it through solid heavy grass. If you're just using it in normal household stuff, you can get 20 to 25 minutes out of it. The reason why this one landed at my house and not in our contractor trailer or in our lawn mowing trailer is that runtime. Would have to carry two batteries in order to do the same amount of work I could do with a different machine with one battery. Is that because the motor is up top and we have a shaft that runs through? I don't know. There is a lot of power here, although the RPMs are lower. Low is going to be around 4,000 RPMs and high on this is going to max out about 5,800. But with that said, because of the 17-inch swath, you really get some great line speed going and this thing cuts like a beast. And secondly, it is butter smooth. You can use this thing all day if you wanted to and it feels great, it cuts great, and there is zero vibrations felt up this grip. This grip is purely DeWalt and once you get over that safety, you will absolutely love it. The step trigger, most people will get used to it, but when I say step trigger, it's not fully variable. It goes in different modes and just watch my finger here and listen. As you get closer to the top, it feels more variable, but realistically it's just taking different points and bumping that motor up as it goes. That was not my finger just moving quickly through that. That was the steps as it goes through. Not a big deal. It ...
#  'summary': "The DeWalt Flex Volt Universal Attachment String Trimmer, a 60-volt tool, is praised for being awesome, smooth, and powerful, reminding the reviewer of a steel. It features a 15 to 17-inch swath and can take universal attachments. The reviewer highlights that this trimmer's balance is off, it's shorter than many, and it's important to be gentle with the head to avoid breakage. The step trigger, which is a stepped trigger, and safety feature are noted as potential annoyances for some. While the trimmer cuts like a beast with zero vibrations, the runtime is about 10 minutes with a 9 amp hour battery. Around the house, the unit does awesome on low only. Despite these drawbacks, the reviewer recommends the unit, particularly for homeowners seeking power and smoothness, with the recommendation to use the 0.080 line and consider upgrading to a 12 or 15 amp hour battery for longer runtime.",
#  'customer_sentiment': {'positives': ['High power and line speed for cutting',
#    'Smooth operation with zero vibrations',
#    'Takes universal attachments',
#    'Good for normal household stuff',
#    'Excellent buy'],
#   'negatives': ['Off balance',
#    'Shorter than many',
#    'Weak head that breaks easily if pounded against ground or rocks',
#    'Inconvenient safety',
#    'Short runtime of about 10 minutes with a 9 amp hour battery',
#    'Stepped trigger that is not fully variable',
#    'Horrible for using it in the yard']}}

# %%
# Split the JSON string into separate JSON objects
json_objects = json_output.split('}\n{')

# Add back the curly braces that were removed during the split
json_objects = [f'{obj}}}' if i == 0 else f'{{{obj}}}' for i, obj in enumerate(json_objects)]

print('json objects: ' +json_objects)
# Parse each JSON object
parsed_jsons = []

for obj in json_objects:
    try:
        print("Attempting to parse JSON object:")
        print(obj)  # Print the JSON object for debugging
        parsed_jsons.append(json.loads(obj))
    except json.JSONDecodeError as e:
        print(f"Error parsing JSON: {e}")
        print(f"Problematic JSON: {obj[:100]}...")  # Print the first 100 characters for context

# Extract the relevant data
if len(parsed_jsons) >= 2:
    full_transcript = parsed_jsons[0].get("transcript", "")
    summary = parsed_jsons[1].get("summary", {})
    sentiment = parsed_jsons[1].get("customer_sentiment", {})

    # Create a DataFrame
    df = pd.DataFrame({
        "transcript": [full_transcript],
        "transcript_summary": [summary]
        # "customer_sentiment": [sentiment]
    })

    # Display the DataFrame
    print(df)
else:
    print("Not enough JSON objects found.")
